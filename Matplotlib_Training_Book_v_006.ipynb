# %% [markdown]
# # Matplotlib Training Book
#
# ### Why I made this notebook?
#
# This Notebook is here to train the Matplotlib.pyplot Library.
# It contains quizzles for all fundamental plt attributes, methods and more.
# The goal is to **master the mechanics through repetition**.
# The work here is based on the book "Python Data Science Handbook" written by Jack VanderPlas, which I really enjoyed reading.
#
# ### Requirements
#
# You should know the theory behind matplotlib.pyplot and have an understanding why the following tasks work.
# This book is just about knowing how to use the code.

# %% [markdown]
# ### Let's get started

# %% [markdown]
# #### Task 1 Installation
#
# 1.1 Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#enter solution

# %% [markdown]
# 1.2 Set Style to classic

# %%
plt.style.use("classic")

# %%
#enter solution

# %% [markdown]
# 1.3 Import NumPy and Pandas

# %%
import numpy as np
import pandas as pd

# %%
#enter solution

# %% [markdown]
# 1.4 Set matplotlib so it will lead to static images of your plot embedded in the notebook

# %%
# %matplotlib inline

# %%
#enter solution

# %% [markdown]
# 1.5 Save the following figure as a .png-file named "my_figure"

# %%
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x, np.sin(x), "-")
plt.plot(x, np.cos(x), "--")

fig.savefig("my_figure.png")

# %%
#enter solution

# %% [markdown]
# 1.6 Show the saved png in jupyter notebook

# %%
from IPython.display import Image

Image("my_figure.png")

# %%
#enter solution

# %% [markdown]
# 1.7 Show the different file types that are supported for saving a chart (e.g. fig)

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
#enter solution

# %% [markdown]
# #### Task 2 Interfaces
#
# 2.1 Create two diagramms in the format of two rows and one column (one for (x, sin(x)) and the other for (x, cos(x))

# %%
plt.figure()

plt.subplot(2,1,1) # rows, columns, panel number
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %%
#enter solution

# %% [markdown]
# 2.2 Create the same but with Figure and Axes objects

# %%
fig, ax = plt.subplots(2)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %%
#enter solution

# %% [markdown]
# #### Task 3 Simple Line Plots
#
# 3.1 Set the style to "seaborn-whitegrid" and create a figure and empty axes

# %%
plt.style.use("seaborn-whitegrid")
fig = plt.figure()
ax = plt.axes()

# %%
#enter solution

# %% [markdown]
# 3.2 Plot the following x and sin(x)

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,1000)

ax.plot(x, np.sin(x))

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,1000)

#enter solution

# %% [markdown]
# 3.3 Use pylab interface to create the same graph

# %%
plt.plot(x, np.sin(x))

# %%
#enter solution

# %% [markdown]
# 3.4 Create the sin(x) and cos(x) line in the same figure

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
#enter solution

# %% [markdown]
# 3.5 Plot all (x, np.sin(x-0)) (x, np.sin(x-1)) ... (x, np.sin(x-5)) using following colors for the line:
#
#     "blue" specify color by name
#     "g" short color code (rgbcmyk)
#     "0.75" Grayscale between 0 and 1
#     "#FFDD44" Hex code (RRGGBB from 00 to FF)
#     (1.0, 0.2 , 0.3) RGB tuple, values 0 and 1
#     "chartreuse" all HTML color names supported

# %%
plt.plot(x, np.sin(x-0), color= "blue")
plt.plot(x, np.sin(x-1), color= "g")
plt.plot(x, np.sin(x-2), color= "0.75")
plt.plot(x, np.sin(x-3), color= "#FFDD44")
plt.plot(x, np.sin(x-4), color= (1.0,0.2,0.3))
plt.plot(x, np.sin(x-5), color= "chartreuse")

# %%
#enter solution

# %% [markdown]
# 3.6 Plot all (x, x + 0) (x, x + 1) ... (x, x + 3) using the following line styles
#
#     solid
#     dashed
#     dashdot
#     dotted

# %%
plt.plot(x, x + 0, linestyle= "solid")
plt.plot(x, x + 1, linestyle= "dashed")
plt.plot(x, x + 2, linestyle= "dashdot")
plt.plot(x, x + 3, linestyle= "dotted")

# %%
#enter solution

# %% [markdown]
# 3.7 Change the followings plot axis limits. x = [-1,11] y = [-1.5 , 1.5]

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

#enter solution

# %% [markdown]
# 3.8 Change the axis limit like above, but reverse it

# %%
plt.plot(x, np.sin(x))

plt.xlim(11, -1)
plt.ylim(1.5, -1.5)
# Out:
# (1.5, -1.5)

# %%
plt.plot(x, np.sin(x))

#enter solution

# %% [markdown]
# 3.9 Change the axis so the line is tighten the bounds around the current plot

# %%
plt.plot(x, np.sin(x))

plt.axis("tight")
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %%
plt.plot(x, np.sin(x))

#enter solution

# %% [markdown]
# 3.10 Change the axis ,so one x unit is equal to one unit in y

# %%
plt.plot(x, np.sin(x))

plt.axis("equal")
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %%
plt.plot(x, np.sin(x))

#enter solution

# %% [markdown]
# 3.11 Put a title "A Sine Curve" to the plot and label the x-axis as "x" and y-axis as "y"

# %%
plt.plot(x, np.sin(x))
plt.title("A Sin Curve")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.plot(x, np.sin(x))

#enter solution

# %% [markdown]
# 3.12 Plot the sin curve as a solid green line, plot the cos curve as a dotted blue line. Add a legend with "sin(x)" and "cos(x)". Set the x-axis equal to the y-axis

# %%
plt.plot(x, np.sin(x), linestyle= "solid", color= "green", label= "sin(x)")
plt.plot(x, np.cos(x), linestyle= "dotted", color= "blue", label= "cos(x)")
plt.axis("equal")

plt.legend()

# %%
#enter solution

# %% [markdown]
# #### Task 4 Simple Scatter Plot
#
# 4.1 Create a scatter plot with the following x and y values using the plot function. Dots have to be black

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

plt.plot(x,y, marker= "o", linestyle= "", color = "black")

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

#enter solution

# %% [markdown]
# This are the different **markers**

# %%
rng= np.random.RandomState(0)
for marker in ["o", ".", ",", "x", "+", "v", "^", "<", ">", "s", "d"]:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0,1.8)

# %% [markdown]
# 4.2 Create a scatter plot with **x** and **y** values using plot function. Connect the dots with a line (both black)

# %%
plt.plot(x,y, marker="o", linestyle="-", color="black")

# %%
#enter solution

# %% [markdown]
# 4.3 Create a scatter plot with **x** and **y** values using scatter function.

# %%
plt.scatter(x,y, marker ="o")

# %%
#enter solution

# %% [markdown]
# 4.4 Create a scatter plot using the following data, change the color, size. Change the transparency to 0.3, show the color scale. Add the cmap keyword and set it to "viridis" to get color.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x,y, c=colors, s=sizes, alpha=0.3, cmap="viridis")
plt.colorbar()

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

#enter solution

# %% [markdown]
# #### Task 5 Visualizing Errors
#
# 5.1 Create an errorbar with the following data

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y,yerr = dy, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

#enter solution

# %% [markdown]
# 5.2 Change the errorbar graph, so the fmt is "o", color of the dots is black, the bars are light gray, the bar width is 3 and the capsize is 0

# %%
plt.errorbar(x,y,yerr = dy, fmt="o", color= "black", ecolor= "lightgray", elinewidth= 3, capsize= 0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#enter solution

# %% [markdown]
# 5.3 Take a look at the following Continious Error

# %%
#import the GaussianProcess 
from sklearn.gaussian_process import GaussianProcessRegressor

# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Compute the Gaussian process fit
gp = GaussianProcessRegressor()
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, y_std = gp.predict(xfit[:, np.newaxis], return_std=True)
dyfit = 2 * np.sqrt(y_std)  # 2*sigma ~ 95% confidence region

#visualize the result
plt.plot(xdata,ydata, "or")
plt.plot(xfit,yfit, "-", color="gray")

plt.fill_between(xfit,yfit - dyfit, yfit + dyfit, color="gray", alpha = 0.2)

plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# #### Task 6 Histograms, Binning and Density
#
# 6.1 Create a histogram with the following data

# %%
data = np.random.randn(1000)

plt.hist(data)
# Out:
# (array([ 12.,  49., 125., 230., 234., 210., 109.,  24.,   6.,   1.]),
#  array([-2.96060929, -2.28876233, -1.61691537, -0.94506841, -0.27322144,
#          0.39862552,  1.07047248,  1.74231944,  2.4141664 ,  3.08601336,
#          3.75786032]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(1000)

#enter solution

# %% [markdown]
# 6.2 Create a histogram wit hthe following customizations
#
#     30 bins
#     normed
#     capacity = 0.5
#     histogram type = "stepfilled"
#     color = steelblue
#     color of edges = none

# %%
plt.hist(data, bins= 30, alpha= .5, histtype= "stepfilled", color= "steelblue", edgecolor= "none")
# Out:
# (array([ 2.,  1., 10.,  4., 10., 12., 17., 36., 33., 34., 64., 50., 59.,
#         69., 75., 84., 68., 68., 59., 65., 42., 41., 34., 15., 21.,  9.,
#         10.,  3.,  0.,  5.]),
#  array([-2.7506217 , -2.56966326, -2.38870482, -2.20774638, -2.02678794,
#         -1.8458295 , -1.66487106, -1.48391262, -1.30295418, -1.12199574,
#         -0.9410373 , -0.76007886, -0.57912042, -0.39816198, -0.21720354,
#         -0.0362451 ,  0.14471334,  0.32567178,  0.50663022,  0.68758866,
#          0.8685471 ,  1.04950554,  1.23046398,  1.41142242,  1.59238086,
#          1.7733393 ,  1.95429774,  2.13525618,  2.31621462,  2.49717306,
#          2.6781315 ]),
#  <a list of 1 Patch objects>)

# %%
#enter solution

# %% [markdown]
# 6.3 Put the following data in one histogram with the given keywords

# %%
x1 = np.random.normal(0,.8,1000)
x2 = np.random.normal(-2,1,1000)
x3 = np.random.normal(3,2,1000)
kwargs = dict(histtype= "stepfilled", alpha= .3, bins= 40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 1.,  0.,  1.,  6.,  4.,  4.,  9., 14., 10., 24., 28., 44., 56.,
#         40., 48., 60., 62., 66., 79., 71., 74., 62., 36., 47., 27., 33.,
#         35., 20., 11., 11.,  5.,  3.,  5.,  3.,  0.,  0.,  0.,  0.,  0.,
#          1.]),
#  array([-3.63102078, -3.27189585, -2.91277092, -2.55364599, -2.19452106,
#         -1.83539613, -1.4762712 , -1.11714627, -0.75802134, -0.39889641,
#         -0.03977148,  0.31935345,  0.67847838,  1.03760331,  1.39672824,
#          1.75585317,  2.1149781 ,  2.47410303,  2.83322796,  3.19235289,
#          3.55147782,  3.91060275,  4.26972768,  4.62885261,  4.98797754,
#          5.34710247,  5.7062274 ,  6.06535233,  6.42447726,  6.78360219,
#          7.14272712,  7.50185205,  7.86097698,  8.22010191,  8.57922684,
#          8.93835177,  9.2974767 ,  9.65660163, 10.01572656, 10.37485149,
#         10.73397642]),
#  <a list of 1 Patch objects>)

# %%
x1 = np.random.normal(0,.8,1000)
x2 = np.random.normal(-2,1,1000)
x3 = np.random.normal(3,2,1000)
kwargs = dict(histtype= "stepfilled", alpha= .3, bins= 40)

#enter solution

# %% [markdown]
# 6.4 Create a two dimensional histogram with the following data (30 bins, color "Blues", Add colorbar, add "counts in bin" to the colorbar

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean,cov, 10000).T

plt.hist2d(x,y, bins= 30, cmap= "Blues")
cb = plt.colorbar()
cb.set_label("counts in bin")

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean,cov, 10000).T

#enter solution

# %% [markdown]
# 6.5 Create the same except it is a hexagonal histogram

# %%
plt.hexbin(x,y, gridsize= 30, cmap= "Blues")
cb = plt.colorbar(label= "count in bins")

# %%
#enter solution

# %% [markdown]
# #### Task 7 Customizing Plot Legends
#
# 7.1 Change the plot style to classic

# %%
plt.style.use("classic")

# %%
#enter solution

# %% [markdown]
# 7.2 Add the label "Sine" and "Cosine" to the legend.

# %%
x= np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "-b", label= "Sine")
ax.plot(x, np.cos(x), "--r", label= "Cosine")
ax.axis("equal")
leg = ax.legend()

# %%
#enter solution
x= np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "-b")
ax.plot(x, np.cos(x), "--r")
ax.axis("equal")
leg = ax.legend()

# %% [markdown]
# 7.3 Do the same as aboth, but set the legend in the upper left corner and turn the fram of the legend off.

# %%
x= np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "-b", label= "Sine")
ax.plot(x, np.cos(x), "--r", label= "Cosine")
ax.axis("equal")
leg = ax.legend(loc= "upper left", frameon= False)

# %%
#enter solution

# %% [markdown]
# 7.4 Change the frame of the legend to rounded, put a shadow on turn the opacity to 0.8 and change the size of the framepad to 1.5

# %%
x= np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "-b", label= "Sine")
ax.plot(x, np.cos(x), "--r", label= "Cosine")
ax.axis("equal")
leg = ax.legend(fancybox= True, framealpha= 0.8, shadow= True, borderpad= 1.5)

# %%
#enter solution
x= np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "-b", label= "Sine")
ax.plot(x, np.cos(x), "--r", label= "Cosine")
ax.axis("equal")

# %% [markdown]
# #### Task 8 Customizing Colorbars
#
# 8.1 Create a simple colorbar for the following data

# %%
x = np.linspace(0,10,1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar()

# %%
#enter solution
x = np.linspace(0,10,1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)

# %% [markdown]
# 8.2 Change the colormap to gray

# %%
x = np.linspace(0,10,1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I, cmap= "gray")
plt.colorbar()

# %%
#enter solution
x = np.linspace(0,10,1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar()

# %% [markdown]
# #### Task 9 Text and Annotation
#
# 9.1 Add text ". Point (5,0)" to the position (5,0) in the following graph

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

plt.plot(x, y)
plt.text(5,0, ". Point (5,0)", size= 9, color= "gray")
# Out:
# Text(5, 0, '. Point (5,0)')

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

#enter solution

# %% [markdown]
# 9.2 Add a arrow with the text "Here" to the following graph. Arrow pointing to (4.7, -1), text at (4.4,0)

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

plt.plot(x,y)
plt.annotate("Here", xy= (4.7, -1), xytext= (4.4, 0), arrowprops= dict(facecolor= "black", shrink= 0.05))
# Out:
# Text(4.4, 0, 'Here')

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

#enter solution

# %% [markdown]
# For later:
#
#     Density and Contour Plots
#     Advanced Colorbar Customization
#     Multiple Subplots
#     Advanced Annotations
#     Customizing Tricks
